# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf

# %%
# Attempt to load the file without specifying any delimiter to check its structure
Tm = pd.read_csv('Tm.asc', delimiter=r'\s+', header=None)
measured_data = pd.read_csv('Tm_measured.txt',skiprows=17, header=None)

# %%
import plotly.express as px

# Create an interactive plot using Plotly
fig = px.line(Tm, x=0, y=1, markers=True, title='Interactive Plot of Column 0 vs Column 1')

# Update labels
fig.update_layout(
    xaxis_title='Wavelength (nm)',
    yaxis_title='Intensity (arb. u.)',
    template='plotly_white'
)

# Display the interactive plot
fig.show()
# Out:
# <div>                            <div id="18f745d1-126a-410c-9688-9c0c7c7fd3e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18f745d1-126a-410c-9688-9c0c7c7fd3e3")) {                    Plotly.newPlot(                        "18f745d1-126a-410c-9688-9c0c7c7fd3e3",                        [{"hovertemplate":"0=%{x}\u003cbr\u003e1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","showlegend":false,"x":[198.0,198.0,198.0,198.0,198.0,198.1,198.1,198.1,198.1,198.1,198.2,198.2,198.2,198.2,198.2,198.3,198.3,198.3,198.3,198.3,198.4,198.4,198.4,198.4,198.4,198.5,198.5,198.5,198.5,198.5,198.6,198.6,198.6,198.6,198.6,198.7,198.7,198.7,198.7,19
# ...

# %%
# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(df[0], df[1], marker='o', linestyle='-', color='b', markersize=2)

# Adding labels and title
plt.xlabel('Column 0')
plt.ylabel('Column 1')
plt.title('Plot of Column 0 vs Column 1')

# Display the plot
plt.grid(True)
plt.show()

# %%
# Configure cufflinks

cf.set_config_file(offline = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
